# %% [markdown]
# <a href="https://colab.research.google.com/github/PiyushYewale/gitupload/blob/main/Prac_7_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practical 7 part 2

# %%
import pandas as pd
df=pd.DataFrame(
    {
        "Roll no":[6001,6002,6003,6004,6005],
        "Name":['Shumaque','Anushka','Piyush','Naufil','Swathi'],
        "Marks":[70,69,70,73,90]
    }
)
print(df)
# Out:
#    Roll no      Name  Marks
# 0     6001  Shumaque     70
# 1     6002   Anushka     69
# 2     6003    Piyush     70
# 3     6004    Naufil     73
# 4     6005    Swathi     90

# %%
df.isnull().sum()
# Out:
# Roll no    0
# Name       0
# Marks      0
# dtype: int64

# %%
df.isnull()
# Out:
#    Roll no   Name  Marks
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False

# %%
df.describe()
# Out:
#            Roll no      Marks
# count     5.000000   5.000000
# mean   6003.000000  74.400000
# std       1.581139   8.848729
# min    6001.000000  69.000000
# 25%    6002.000000  70.000000
# 50%    6003.000000  70.000000
# 75%    6004.000000  73.000000
# max    6005.000000  90.000000

# %%
df.describe(include='object')
# Out:
#             Name
# count          5
# unique         5
# top     Shumaque
# freq           1

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
df.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  5 non-null      int64
#  1   Name     5 non-null      object
#  2   Marks    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes
# <bound method DataFrame.info of    Roll no      Name  Marks
# 0     6001  Shumaque     70
# 1     6002   Anushka     69
# 2     6003    Piyush     70
# 3     6004    Naufil     73
# 4     6005    Swathi     90>

# %%
df.nunique()
# Out:
# Roll no    5
# Name       5
# Marks      4
# dtype: int64

# %%
df.duplicated()
# Out:
# <bound method DataFrame.duplicated of    Roll no      Name  Marks
# 0     6001  Shumaque     70
# 1     6002   Anushka     69
# 2     6003    Piyush     70
# 3     6004    Naufil     73
# 4     6005    Swathi     90>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.value_counts()
# Out:
# Roll no  Name      Marks
# 6001     Shumaque  70       1
# 6002     Anushka   69       1
# 6003     Piyush    70       1
# 6004     Naufil    73       1
# 6005     Swathi    90       1
# dtype: int64

# %%
df['Name'].value_counts()
#will not take whole dataset but only a specified column
# Out:
# Shumaque    1
# Anushka     1
# Piyush      1
# Naufil      1
# Swathi      1
# Name: Name, dtype: int64

# %%
df['Name']
# Out:
# 0    Shumaque
# 1     Anushka
# 2      Piyush
# 3      Naufil
# 4      Swathi
# Name: Name, dtype: object

# %%
correlation=df.corr()
# Out:
# <ipython-input-29-0c9b4bd1cb53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()

# %%
df.corr()
# Out:
# <ipython-input-31-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Roll no     Marks
# Roll no  1.000000  0.786216
# Marks    0.786216  1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['Roll no'].plot(kind='hist', bins=20, title='Roll no')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Marks'].plot(kind='hist', bins=20, title='Marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(correlation,annot=True, fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.mean()
# Out:
# <ipython-input-43-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Roll no    6003.0
# Marks        74.4
# dtype: float64

# %%
df.var()
# Out:
# <ipython-input-46-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll no     2.5
# Marks      78.3
# dtype: float64

# %%
df['Marks'].var()
# Out:
# 78.3

# %%
df.cov()
# Out:
# <ipython-input-49-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#          Roll no  Marks
# Roll no      2.5   11.0
# Marks       11.0   78.3
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20['Roll no'].plot(kind='hist', bins=20, title='Roll no')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['Marks'].plot(kind='hist', bins=20, title='Marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...
